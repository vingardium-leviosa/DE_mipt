# %% [markdown]
# 1.Вывести все уникальные бренды, у которых стандартная стоимость выше 1500 долларов.  Ответ: 4 бренда

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.Вывести все подтвержденные транзакции за период '2017-04-01' по '2017-04-09' включительно. Ответ: 531 транзакция

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Вывести все профессии у клиентов из сферы IT или Financial Services, которые начинаются с фразы 'Senior'. Ответ: 6 уникальных значений

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Вывести все бренды, которые закупают клиенты, работающие в сфере Financial Services. Ответ: 7 значений

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5.Вывести 10 клиентов, которые оформили онлайн-заказ продукции из брендов 'Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles'.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6.Вывести всех клиентов, у которых нет транзакций. Ответ: 507 значений

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Вывести всех клиентов из IT, у которых транзакции с максимальной стандартной стоимостью. Ответ: 9 клиентов

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. Вывести всех клиентов из сферы IT и Health, у которых есть подтвержденные транзакции за период '2017-07-07' по '2017-07-17'. Ответ: 115 уникальных значений

# %% [markdown]
# ![image.png](data:image/png;base64,...)
